# %% [markdown]
# <h1>Itsy Bitsy M4 (IBM4)</h1>
#
# This Jupyter Notebook has the different methods to operate your IBM4. Each block (or cell) can be executed independently, according to what you need to do. The <b>output</b> of the block will appear <b>below</b> it.
# <br><br>
# To execute a cell, press execute cell next to it, or use <b>Ctrl + Alt + Enter</b>
# <br><br>
# <em>IMPORTANT:</em> Make sure you have this notebook in the <em>same folder</em> where the other IBM4 python scripts are located (i.e. Control_Examples, IBM4_Lib, Sweep_Interval)

# %% [markdown]
# <h2><strong>FIRST</strong> Import packages</h2>
# <b><i>ATTENTION</b></i>: In order for the code blocks to work you <b>MUST</b> run the block below first.
# It will output your working folder if successful.

# %%
"""
Script for running the Methods from Control_Examples.py
R. Sheehan 19 - 9 - 2024
"""

import os
import Control_Examples
# Where are you? 
pwd = os.getcwd()
print(pwd)
# Out:
# c:\TO\PY2108_dev

# %% [markdown]
# <h2>Code blocks for PY2108</h2>
#
# You can run any of the following blocks depending on your needs. To clear the output, select the output and press <b>Alt + Delete</b>

# %%
# 0. Basic Find, Open, Close
Control_Examples.Simple_Open_Close()
# Out:
# Communication with: COM3  is open
# IBM4 IDN string: b'ISBY-UCC-RevA.1'
# Closing Serial link with: COM3

# %%
# 1. Step through voltages
Control_Examples.Step_Through_Voltages()

# %%
# 2. Basic single channel sweep
Control_Examples.Simple_Sweep()

# %%
# 3. Read all input channels
Control_Examples.Simple_Sweep_Read_All()

# %%
# 4. Differential read
Control_Examples.Differential_Readings()

# %%
# 5. Multi-reads and timings
Control_Examples.Multiple_Readings()

# %%
# 6. Multimeter mode
Control_Examples.Multimeter_Mode()

# %%
# 7. Linear single channel sweep
#Control_Examples.Linear_Sweep_V1()
Control_Examples.Linear_Sweep_V2()

# %% [markdown]
# <h2>Need help?</h2>
# <a href="https://realpython.com/jupyter-notebook-introduction/">Jupyter Notebook: An Introduction</a>
# <br>
# <a href="https://code.visualstudio.com/docs/datascience/jupyter-notebooks">Jupyter Notebooks in VS Code</a>
# <br>
# <a href="https://jupyter.org/try">Try Jupyter (good for practicing!)</a>
